# %%
# Importing all necessary libraries
import cv2
import os
  
# Read the video from specified path
cam = cv2.VideoCapture("C:\\users\\tirumva2\\Downloads\\ag_oms_videos\\terence_unsafe.mp4")
  
try:
      
    # creating a folder named data
    if not os.path.exists('data1'):
        os.makedirs('data1')
  
# if not created then raise error
except OSError:
    print ('Error: Creating directory of data1')
  
# frame
currentframe = 0
  
while(True):
      
    # reading from frame
    ret,frame = cam.read()
  
    if ret:
        # if video is still left continue creating images
        name = './data1/' + "{:05d}".format(currentframe) + ".jpg"
        print ('Creating...' + name)
  
        # writing the extracted images
        cv2.imwrite(name, frame)
  
        # increasing counter so that it will
        # show how many frames are created
        currentframe += 1
    else:
        break
  
# Release all space and windows once done
cam.release()
cv2.destroyAllWindows()
# Out:
# Creating..../data1/00000.jpg
# Creating..../data1/00001.jpg
# Creating..../data1/00002.jpg
# Creating..../data1/00003.jpg
# Creating..../data1/00004.jpg
# Creating..../data1/00005.jpg
# Creating..../data1/00006.jpg
# Creating..../data1/00007.jpg
# Creating..../data1/00008.jpg
# Creating..../data1/00009.jpg
# Creating..../data1/00010.jpg
# Creating..../data1/00011.jpg
# Creating..../data1/00012.jpg
# Creating..../data1/00013.jpg
# Creating..../data1/00014.jpg
# Creating..../data1/00015.jpg
# Creating..../data1/00016.jpg
# Creating..../data1/00017.jpg
# Creating..../data1/00018.jpg
# Creating..../data1/00019.jpg
# Creating..../data1/00020.jpg
# Creating..../data1/00021.jpg
# Creating..../data1/00022.jpg
# Creating..../data1/00023.jpg
# Creating..../data1/00024.jpg
# Creating..../data1/00025.jpg
# Creating..../data1/00026.jpg
# Creating..../data1/00027.jpg
# Creating..../data1/00028.jpg
# Creating..../data1/00029.jpg
# Creating..../data1/00030.jpg
# Creating..../data1/00031.jpg
# ...

# %%
import cv2
 
# Opens the Video file
cap= cv2.VideoCapture('C:/users/tirumva2/Downloads/terence_safe.mp4')
i=0
while(cap.isOpened()):
    ret, frame = cap.read()
    if ret == False:
        break
    cv2.imwrite('kang'+str(i)+'.jpg',frame)
    i+=1
 
cap.release()
cv2.destroyAllWindows()

# %%
# Importing all necessary libraries
import cv2
import os
  
# Read the video from specified path
cam = cv2.VideoCapture("C:\\Users\\Admin\\PycharmProjects\\project_1\\openCV.mp4")
  
try:
      
    # creating a folder named data
    if not os.path.exists('data1'):
        os.makedirs('data1')
  
# if not created then raise error
except OSError:
    print ('Error: Creating directory of data')
  
# frame
currentframe = 0
  
while(True):
      
    # reading from frame
    ret,frame = cam.read()
  
    if ret:
        # if video is still left continue creating images
        name = './data/frame' + str(currentframe) + '.jpg'
        print ('Creating...' + name)
  
        # writing the extracted images
        cv2.imwrite(name, frame)
  
        # increasing counter so that it will
        # show how many frames are created
        currentframe += 1
    else:
        break
  
# Release all space and windows once done
cam.release()
cv2.destroyAllWindows()

# %%
class student:
    num_of_students = 0
    extra_credit = 0.2
    def __init__(self, name, age, gpa):
        self.name = name
        self.age = age
        self.gpa = gpa
        student.num_of_students +=1
    def email(self):
        return '{}'.format(self.name) + '@school.edu'
    
    def increase_gpa(self):
        self.gpa = float(self.gpa + self.extra_credit)
        
    @classmethod
    def set_extra_credit(cls, points):
        cls.extra_credit = points
        
    @classmethod
    def from_string(cls, stu_str):
        name, age, gpa = stu_str.split('-')
        return cls(name, age, gpa)
    
    @staticmethod
    def study_day(day):
        if day.weekday()== 5 or day.weekday() == 6:
            return False
        return True
    
import datetime
my_date = datetime.date(2021, 5, 30)
print(student.study_day(my_date))

    
stu1 = student('Terry', 21, 3.8)
stu2 = student('Emmy', 20, 2.7)

stu1_str = 'Togy-21-3.6'
new_stu = student.from_string(stu1_str)
print(new_stu.email())
print(new_stu.gpa)

#student.set_extra_credit(0.3)
#print(student.extra_credit)
#print(stu1.extra_credit)
#print(stu2.extra_credit)

#print(student.num_of_students)
#print(stu2.extra_credit)
#print(stu2.gpa)
#stu2.increase_gpa()
#print(stu2.gpa)
# Out:
# False
# Togy@school.edu
# 3.6

# %%
import numpy as np
import matplotlib.pyplot as plt


def get_joint(x, idx):
    px = x[2*idx]
    py = x[2*idx+1]
    return px, py


def set_joint(x, idx, px, py):
    x[2*idx] = px
    x[2*idx+1] = py
    return


def get_an_example_of_standing_skeleton():
    data = [3, 4, 3027, "squat", "squat_03-08-20-26-57-195/00999.jpg", 0.4024390243902439, 0.13858695652173914, 0.4451219512195122, 0.19972826086956524, 0.4329268292682927, 0.19565217391304346, 0.3932926829268293, 0.25271739130434784, 0.0, 0.0, 0.4573170731707317, 0.2078804347826087, 0.3871951219512195, 0.25679347826086957, 0.3475609756097561, 0.27309782608695654, 0.49085365853658536, 0.4116847826086957, 0.43902439024390244, 0.5339673913043479, 0.47560975609756095, 0.6440217391304348, 0.49390243902439024, 0.36277173913043476, 0.0, 0.0, 0.0, 0.0, 0.4054878048780488, 0.12635869565217392, 0.4146341463414634, 0.12635869565217392, 0.0, 0.0, 0.45121951219512196, 0.13858695652173914]
    skeleton = np.array(data[5:])
    return skeleton


def get_a_normalized_standing_skeleton():
    x = get_an_example_of_standing_skeleton()

    NECK = 1
    L_THIGH = 8
    R_THIGH = 11

    # Remove offset by setting neck as origin
    x0, y0 = get_joint(x, NECK)
    x[::2] -= x0
    x[1::2] -= y0

    # Scale the skeleton by taking neck-thigh distance as height
    x0, y0 = get_joint(x, NECK)
    _, y11 = get_joint(x, L_THIGH)
    _, y12 = get_joint(x, R_THIGH)
    y1 = (y11 + y12) / 2
    height = abs(y0 - y1)
    x /= height
    return x


def draw_skeleton_joints(skeleton):
    x = skeleton[::2]
    y = skeleton[1::2]
    plt.plot(-x, -y, "r*")
    plt.axis("equal")
    plt.show()


if __name__ == "__main__":
    skeleton = get_a_normalized_standing_skeleton()
    draw_skeleton_joints(skeleton)
